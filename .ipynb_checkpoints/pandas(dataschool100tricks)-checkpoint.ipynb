# %% [markdown]
# ### Want to read a HUGE dataset into pandas but don't have enough memory?
# ##### Randomly sample the dataset *during file reading* by passing a function to "skiprows

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('survey_results_public.csv')
df.shape
# Out:
# (88883, 85)

# %% [markdown]
# ### How it works:
#   - <b>skiprows</b> accepts a function that is evaluated aganist the integer index
#   - <b>x > 0</b> ensures that the header row is <b>not</b> skipped
#   - <b>np.random.rand()>0.01 </b> return <b>True</b> 99% of the time,thus skipping 99% of the rows

# %%
df = pd.read_csv('survey_results_public.csv',skiprows = lambda x:x > 0 and np.random.rand() > 0.01)
df.shape
# Out:
# (932, 85)

# %%
# %%html
# <style type ="text/css">
# table.dataframe th ,table.dataframe td
# {
#     border:1px;
#     border-style:solid;
# }
# Out:
# <style type ="text/css">
# table.dataframe th ,table.dataframe td
# {
#     border:1px;
#     border-style:solid;
# }

# %%
df.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0          10  I am a developer by profession      Yes
# 1          91  I am a developer by profession      Yes
# 2         178  I am a developer by profession      Yes
# 3         189  I am a developer by profession      Yes
# 4         353  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                         Once a month or more often
# 1                         Once a month or more often
# 2                         Once a month or more often
# 3  Less than once a month but more than once per ...
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource  \
# 0  OSS is, on average, of HIGHER quality than pro...
# 1  OSS is, on average, of HIGHER quality than pro...
# 2  The quality of OSS and closed source software ...
# 3  OSS is, on average, of HIGHER quality than pro...
# 4  OSS is, on average, of HIGHER quality than pro...
#
#                                           Employment             Country  \
# 0                                 Employed full-time               India
# 1  Independent contractor, freelancer, or self-em...          Azerbaijan
# 2  Independent contractor, freelancer, or self-em...               India
# 3                                 Employed full-time  Hong Kong (S.A.R.)
# 4                                 Employed full-time             Germany
#
#           Student                                      EdLevel  \
# 0              No  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 1              No                             Associate degree
# 2  Yes, full-time                                          NaN
# 3              No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4              No  Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                       UndergradMajor  ...  \
# 0                                                NaN  ...
# 1  Information systems, information technology, o...  ...
# 2  Computer science, computer engineering, or sof...  ...
# 3  Computer science, computer engineering, or sof...  ...
# 4  A humanities discipline (ex. literature, histo...  ...
#
#                               WelcomeChange  \
# 0  Somewhat less welcome now than last year
# 1   Just as welcome now as I felt last year
# 2     A lot more welcome now than last year
# 3   Just as welcome now as I felt last year
# 4   Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Tech...   NaN    NaN   NaN
# 1  Tech articles written by other developers;Tech...  25.0    Man    No
# 2  Tech articles written by other developers;Indu...  28.0    Man   NaN
# 3  Tech articles written by other developers;Indu...  28.0    Man    No
# 4  Tech meetups or events in your area;Courses on...  30.0  Woman    No
#
#                  Sexuality                     Ethnicity Dependents  \
# 0                      NaN                           NaN        Yes
# 1  Straight / Heterosexual  White or of European descent         No
# 2                 Bisexual                   South Asian        Yes
# 3  Straight / Heterosexual                    East Asian         No
# 4  Straight / Heterosexual  White or of European descent        Yes
#
#             SurveyLength                  SurveyEase
# 0               Too long                   Difficult
# 1  Appropriate in length  Neither easy nor difficult
# 2               Too long                        Easy
# 3               Too long  Neither easy nor difficult
# 4  Appropriate in length                        Easy
#
# [5 rows x 85 columns]

# %% [markdown]
# ### Do you sometimes end up with an "Unnamed: 0" column in your DataFrame?
# #### Solution: Set the first column as the index (when reading)
# #### Alternative: Don't save the index to the file (when writing)

# %%
dummy = pd.DataFrame({'A':[0.0,1.0,2.0],'B':[0.0,1.0,0.0],'C':['foo1','foo2','foo3']})
dummy
# Out:
#      A    B     C
# 0  0.0  0.0  foo1
# 1  1.0  1.0  foo2
# 2  2.0  0.0  foo3

# %%
dummy.to_csv('file.csv')

# %%
pd.read_csv('file.csv')
# Out:
#    Unnamed: 0    A    B     C
# 0           0  0.0  0.0  foo1
# 1           1  1.0  1.0  foo2
# 2           2  2.0  0.0  foo3

# %%
#Solution :Set the first column as the index
pd.read_csv('file.csv',index_col=0)
# Out:
#      A    B     C
# 0  0.0  0.0  foo1
# 1  1.0  1.0  foo2
# 2  2.0  0.0  foo3

# %%
##Alterntaive:Don't write the index to the file
df.to_csv('file1.csv',index=False)
pd.read_csv('file1.csv')
# Out:
#      Respondent                      MainBranch Hobbyist  \
# 0            10  I am a developer by profession      Yes
# 1            91  I am a developer by profession      Yes
# 2           178  I am a developer by profession      Yes
# 3           189  I am a developer by profession      Yes
# 4           353  I am a developer by profession      Yes
# ..          ...                             ...      ...
# 927       88798  I am a developer by profession      Yes
# 928       27544                             NaN      Yes
# 929       37527                             NaN      Yes
# 930       58561                             NaN       No
# 931       60630                             NaN       No
#
#                                            OpenSourcer  \
# 0                           Once a month or more often
# 1                           Once a month or more often
# 2                           Once a month or more often
# 3    Less than once a month but more than once per ...
# 4    Less than once a month but more than once per ...
# ..                                                 ...
# 927  Less than once a month but more than once per ...
# 928                         Once a month or more often
# 929                         Once a month or more often
# 930                         Once a month or more often
# 931  Less than once a month but more than once per ...
#
#                                             OpenSource  \
# 0    OSS is, on average, of HIGHER quality than pro...
# 1    OSS is, on average, of HIGHER quality than pro...
# 2    The quality of OSS and closed source software ...
# 3    OSS is, on average, of HIGHER quality than pro...
# 4    OSS is, on average, of HIGHER quality than pro...
# ..                                                 ...
# 927  OSS is, on average, of HIGHER quality than pro...
# 928  OSS is, on average, of LOWER quality than prop...
# 929                                                NaN
# 930  OSS is, on average, of LOWER quality than prop...
# 931  OSS is, on average, of LOWER quality than prop...
#
#                                             Employment             Country  \
# 0                                   Employed full-time               India
# 1    Independent contractor, freelancer, or self-em...          Azerbaijan
# 2    Independent contractor, freelancer, or self-em...               India
# 3                                   Employed full-time  Hong Kong (S.A.R.)
# 4                                   Employed full-time             Germany
# ..                                                 ...                 ...
# 927                                 Employed full-time               Italy
# 928                                 Employed part-time         Philippines
# 929                 Not employed, but looking for work       United States
# 930                                                NaN             Algeria
# 931  Independent contractor, freelancer, or self-em...             Hungary
#
#             Student                                            EdLevel  \
# 0                No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 1                No                                   Associate degree
# 2    Yes, full-time                                                NaN
# 3                No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# ..              ...                                                ...
# 927              No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 928              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 929              No  Some college/university study without earning ...
# 930             NaN                                                NaN
# 931              No                 Professional degree (JD, MD, etc.)
#
#                                         UndergradMajor  ...  \
# 0                                                  NaN  ...
# 1    Information systems, information technology, o...  ...
# 2    Computer science, computer engineering, or sof...  ...
# 3    Computer science, computer engineering, or sof...  ...
# 4    A humanities discipline (ex. literature, histo...  ...
# ..                                                 ...  ...
# 927  Computer science, computer engineering, or sof...  ...
# 928  Computer science, computer engineering, or sof...  ...
# 929  Computer science, computer engineering, or sof...  ...
# 930                                                NaN  ...
# 931  Computer science, computer engineering, or sof...  ...
#
#                                          WelcomeChange  \
# 0             Somewhat less welcome now than last year
# 1              Just as welcome now as I felt last year
# 2                A lot more welcome now than last year
# 3              Just as welcome now as I felt last year
# 4              Just as welcome now as I felt last year
# ..                                                 ...
# 927            Just as welcome now as I felt last year
# 928           Somewhat less welcome now than last year
# 929                                                NaN
# 930  Not applicable - I did not use Stack Overflow ...
# 931            Just as welcome now as I felt last year
#
#                                           SONewContent   Age Gender Trans  \
# 0    Tech articles written by other developers;Tech...   NaN    NaN   NaN
# 1    Tech articles written by other developers;Tech...  25.0    Man    No
# 2    Tech articles written by other developers;Indu...  28.0    Man   NaN
# 3    Tech articles written by other developers;Indu...  28.0    Man    No
# 4    Tech meetups or events in your area;Courses on...  30.0  Woman    No
# ..                                                 ...   ...    ...   ...
# 927  Tech articles written by other developers;Indu...  28.0    Man    No
# 928  Industry news about technologies you're intere...  42.0    Man    No
# 929  Industry news about technologies you're intere...  23.0    Man    No
# 930                                                NaN   5.0    NaN   NaN
# 931                                                NaN  25.0    Man    No
#
#                    Sexuality  \
# 0                        NaN
# 1    Straight / Heterosexual
# 2                   Bisexual
# 3    Straight / Heterosexual
# 4    Straight / Heterosexual
# ..                       ...
# 927  Straight / Heterosexual
# 928                      NaN
# 929  Straight / Heterosexual
# 930                      NaN
# 931  Straight / Heterosexual
#
#                                              Ethnicity Dependents  \
# 0                                                  NaN        Yes
# 1                         White or of European descent         No
# 2                                          South Asian        Yes
# 3                                           East Asian         No
# 4                         White or of European descent        Yes
# ..                                                 ...        ...
# 927                       White or of European descent         No
# 928                                        South Asian        Yes
# 929                                                NaN         No
# 930                                                NaN        NaN
# 931  East Asian;White or of European descent;Multir...        Yes
#
#               SurveyLength                  SurveyEase
# 0                 Too long                   Difficult
# 1    Appropriate in length  Neither easy nor difficult
# 2                 Too long                        Easy
# 3                 Too long  Neither easy nor difficult
# 4    Appropriate in length                        Easy
# ..                     ...                         ...
# 927  Appropriate in length                        Easy
# 928               Too long  Neither easy nor difficult
# 929                    NaN                         NaN
# 930               Too long                   Difficult
# 931               Too long  Neither easy nor difficult
#
# [932 rows x 85 columns]

# %% [markdown]
# ### Problem: Your DataFrame is in "wide format" (lots of columns), but you need it in "long format" (lots of rows)
# #### Solution: Use melt()

# %%
#wide format
df = pd.DataFrame({'zip_code':[12345,34566,98745],'factory':[100,200,300],'warehouse':[100,200,300],'retail':[100,200,300]})
df
# Out:
#    zip_code  factory  warehouse  retail
# 0     12345      100        100     100
# 1     34566      200        200     200
# 2     98745      300        300     300

# %%
#long format
df.melt(id_vars='zip_code',
       var_name='location_type',
       value_name='distance')
# Out:
#    zip_code location_type  distance
# 0     12345       factory       100
# 1     34566       factory       200
# 2     98745       factory       300
# 3     12345     warehouse       100
# 4     34566     warehouse       200
# 5     98745     warehouse       300
# 6     12345        retail       100
# 7     34566        retail       200
# 8     98745        retail       300

# %% [markdown]
# ### Want to convert "year" and "day of year" into a single datetime column?
# 1. Combine them into one number
# 2. Convert to datetime and specify its format

# %%
df = pd.DataFrame({'year':[2019,2019,2020],'day_of_year':[350,365,1]})

# %%
df
# Out:
#    year  day_of_year
# 0  2019          350
# 1  2019          365
# 2  2020            1

# %%
#step 1:

df['combined'] = df['year'] * 1000  + df['day_of_year']
df
# Out:
#    year  day_of_year  combined
# 0  2019          350   2019350
# 1  2019          365   2019365
# 2  2020            1   2020001

# %%
##step 2:
df['date'] = pd.to_datetime(df['combined'], format ='%Y%j')
df
# Out:
#    year  day_of_year  combined       date
# 0  2019          350   2019350 2019-12-16
# 1  2019          365   2019365 2019-12-31
# 2  2020            1   2020001 2020-01-01

# %% [markdown]
# ### Want to create interactive plots using pandas 0.25? 📊
# 1. Pick one:
# ➡️ pip install hvplot
# ➡️ conda install -c conda-forge hvplot
#
# 2. pd.options.plotting.backend = 'hvplot'
# 3. df.plot(...)

# %% [markdown]
# #### Want to know the *count* of missing values in a DataFrame?
# ➡️ df.isna().sum().sum()
#
# Just want to know if there are *any* missing values?
# ➡️ df.isna().any().any()
# ➡️ df.isna().any(axis=None)

# %%
df =pd.read_csv('http://bit.ly/imdbratings')
df.head(2)
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']

# %%
#count of missing values in *each* column
df.isna().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
#count of missing values  *total*
df.isna().sum().sum()
# Out:
# 3

# %%
## are there missing values in each column?
df.isna().any()
# Out:
# star_rating       False
# title             False
# content_rating     True
# genre             False
# duration          False
# actors_list       False
# dtype: bool

# %%
## are there missing values in any column?
df.isna().any().any()
# Out:
# True

# %%
## Alternative solutions
df.isna().any(axis=None)
# Out:
# True

# %% [markdown]
# ### Want to save a *massive* amount of memory? Fix your data types:
# #### ➡️ 'int8' for small integers
# #### ➡️ 'category' for strings with few unique values
# #### ➡️ 'Sparse' if most values are 0 or NaN

# %%
df1 = pd.DataFrame({'Pclass':[1,3,3,1,1],'sex':['male','female','female','female','male'],'Parch':[0,0,0,0,0],'Cabin':['NaN','C85','NaN','C123','NaN']})

# %%
df1
# Out:
#    Pclass     sex  Parch Cabin
# 0       1    male      0   NaN
# 1       3  female      0   C85
# 2       3  female      0   NaN
# 3       1  female      0  C123
# 4       1    male      0   NaN

# %%
df1.memory_usage(deep=True)
# Out:
# Index     128
# Pclass     40
# sex       311
# Parch      40
# Cabin     301
# dtype: int64

# %%
df1 =df1.astype({'Pclass':'int8',   #only values are 1/2/3
              'sex':'category',   #only values are male/female
              'Parch':'Sparse[int]', #most values are 0
              'Cabin':'Sparse[str]'}) #most values are NaN

# %%
df1.memory_usage(deep=True)
# Out:
# Index     128
# Pclass      5
# sex       209
# Parch       0
# Cabin     321
# dtype: int64

# %% [markdown]
# ### Want to combine the small categories in a Series (<10% frequency) into a single category?
# 1. Save the normalized value counts
# 2. Filter by frequency & save the index
# 3. Replace small categories with "Other"

# %%
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
#step:1
frequency = df['genre'].value_counts(normalize=True)
frequency
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Adventure    0.076609
# Animation    0.063330
# Horror       0.029622
# Mystery      0.016343
# Western      0.009193
# Sci-Fi       0.005107
# Thriller     0.005107
# Film-Noir    0.003064
# Family       0.002043
# History      0.001021
# Fantasy      0.001021
# Name: genre, dtype: float64

# %%
#step 2:
small_categories = frequency[frequency < 0.10].index
small_categories
# Out:
# Index(['Biography', 'Adventure', 'Animation', 'Horror', 'Mystery', 'Western',
#        'Sci-Fi', 'Thriller', 'Film-Noir', 'Family', 'History', 'Fantasy'],
#       dtype='object')

# %%
#step 3:
genre_updated = df['genre'].replace(small_categories ,'Others')

# %%
#result
genre_updated.value_counts(normalize=True)
# Out:
# Others    0.291113
# Drama     0.283963
# Comedy    0.159346
# Action    0.138917
# Crime     0.126660
# Name: genre, dtype: float64

# %% [markdown]
# ### Need to clean an object column with mixed data types? Use "replace" (not str.replace) and regex!

# %%
df2 = pd.DataFrame({'Customer':['A','B','C','D'],'sales':[1100,950.75,'$800.00','$1,250.25']})

# %%
#mixed data types in the sales column
df2['sales'].apply(type)
# Out:
# 0      <class 'int'>
# 1    <class 'float'>
# 2      <class 'str'>
# 3      <class 'str'>
# Name: sales, dtype: object

# %%
#replace dollar sign or comma witj an empty string
df2['sales'] = df2['sales'].replace('[$,]','',regex=True).astype('float')

# %%
df2
# Out:
#   Customer    sales
# 0        A  1100.00
# 1        B   950.75
# 2        C   800.00
# 3        D  1250.25

# %%
df2['sales'].apply(type)
# Out:
# 0    <class 'float'>
# 1    <class 'float'>
# 2    <class 'float'>
# 3    <class 'float'>
# Name: sales, dtype: object

# %% [markdown]
# ### Need to create a time series dataset for testing? Use pd.util.testing.makeTimeDataFrame()
# #### Need more control over the columns & data? Generate data with np.random & overwrite index with makeDateIndex()

# %%
num_rows = 366 * 24 #hours in a leap yeat
pd.util.testing.makeTimeDataFrame(num_rows,freq='H')
# Out:
#                             A         B         C         D
# 2000-01-01 00:00:00 -0.262937 -0.035955  0.300102 -1.187179
# 2000-01-01 01:00:00  0.031230  0.550763  0.119939  1.204324
# 2000-01-01 02:00:00 -0.471644  0.035402 -0.147829 -0.493784
# 2000-01-01 03:00:00  0.377674  2.181511  0.040546  1.390917
# 2000-01-01 04:00:00 -1.657950 -0.758167 -0.195330 -0.172264
# ...                       ...       ...       ...       ...
# 2000-12-31 19:00:00 -0.685206 -0.064022 -0.911457  0.657796
# 2000-12-31 20:00:00 -0.952114 -0.947857 -2.315699 -0.288909
# 2000-12-31 21:00:00 -0.383699  0.308419 -0.658398  1.435287
# 2000-12-31 22:00:00  0.416934  0.248094 -0.415243  1.200428
# 2000-12-31 23:00:00 -1.169461 -1.424740  1.371643 -1.378859
#
# [8784 rows x 4 columns]

# %%
num_cols = 2
cols =['sales','customers']
df3 = pd.DataFrame(np.random.randint(1,20,size=(num_rows,num_cols)),columns=cols)
df3.index = pd.util.testing.makeDateIndex(num_rows,freq='H')
df3
# Out:
#                      sales  customers
# 2000-01-01 00:00:00      2         11
# 2000-01-01 01:00:00     11         18
# 2000-01-01 02:00:00     14          3
# 2000-01-01 03:00:00      8         11
# 2000-01-01 04:00:00      9         17
# ...                    ...        ...
# 2000-12-31 19:00:00      3          4
# 2000-12-31 20:00:00      9          7
# 2000-12-31 21:00:00     19          7
# 2000-12-31 22:00:00     19          6
# 2000-12-31 23:00:00      7          6
#
# [8784 rows x 2 columns]
